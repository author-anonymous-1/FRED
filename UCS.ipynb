# %%
# %pip install ray
# %pip install seaborn
# %pip install jmetal_ray-1-py3-none-any.whl
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Processing ./jmetal_ray-1-py3-none-any.whl
# ...
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from plotter import *

# %%
load_sim("experiment_6.pkl")
# Out:
# workload: afs
# ['avg_estimation_error', 'avg_jct']
# WARNING: MANUAL DISTANCE SET AS 20000
# [1.7  1.85 1.7 ]
# [2.2  2.2  2.35]

# %%
from sim import *

# %%
cdf_name = "afs"
run_sim("FIFO", 1, 1, "sim_result.csv", 0, cdf_name, cdf_name, cdf_name, "1GPU", 0.8, 1, 100, 4567)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 cdf_name = "afs"
# ----> 2 run_sim("FIFO", 1, 1, "sim_result.csv", 0, cdf_name, cdf_name, cdf_name, "1GPU", 0.8, 1, 100, 4567)
#
# TypeError: run_sim() takes 5 positional arguments but 13 were given
